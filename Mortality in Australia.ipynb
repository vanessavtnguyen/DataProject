# %% [markdown]
# # Mortality in Australia
#
# Mortality data plays a vital role in anaylsing demographic transition and provides a snapshot on the current standard of health in each community. The years that are potentially lost and the cause assist health authorities in improving the overall wellbeing of the population.
#
# This dataset focuses on how the mortality rates in Australia have changed in the past millenium.

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import seaborn as sns
import matplotlib.patches as mpatches

shp_file_name = "States Map.shp"

# %%
saved_style_state = matplotlib.rcParams.copy()

# %%
def retrievingdata(filepath):
    if os.path.isfile(filepath):
        print("loading")
        print("done")
    else:
        print("Insert file")
    return(pd.read_csv(filepath,low_memory=False))

# %% [markdown]
# ## Number of Deaths 1907 - 2017

# %%
number_of_deaths = retrievingdata("Number_of_Deaths.csv")
# Out:
# loading
# done

# %%
number_of_deaths['Males'] = number_of_deaths['Males'].astype(str).str.replace(',','').astype(int)
number_of_deaths['Females'] = number_of_deaths['Females'].astype(str).str.replace(',','').astype(int)
number_of_deaths['Total'] = number_of_deaths['Total'].astype(str).str.replace(',','').astype(int)
number_of_deaths[['Males','Females','Total']] = number_of_deaths[['Males','Females','Total']].div(1000)
number_of_deaths
# Out:
#      Year   Males  Females    Total
# 0    1907  25.939   19.366   45.305
# 1    1908  26.632   19.794   46.426
# 2    1909  25.514   18.658   44.172
# 3    1910  26.154   19.436   45.590
# 4    1911  27.591   20.278   47.869
# ..    ...     ...      ...      ...
# 106  2013  75.782   71.896  147.678
# 107  2014  78.341   75.239  153.580
# 108  2015  81.330   77.722  159.052
# 109  2016  81.867   76.637  158.504
# 110  2017  82.858   78.051  160.909
#
# [111 rows x 4 columns]

# %%
plt.figure(figsize=(20, 10))
sns.set_style("whitegrid")
plt.plot(number_of_deaths['Year'], number_of_deaths['Males'], label="Males", color='#6873E3')
plt.plot(number_of_deaths['Year'], number_of_deaths['Females'], label="Females", color='#E368C5')
plt.plot(number_of_deaths['Year'], number_of_deaths['Total'], label="Total", color='#68E387')
plt.legend(prop={"size":15})
plt.title("Number of Deaths 1907 to 2017", fontsize=28, fontweight='bold')
plt.xlabel("Years")
plt.ylabel("Number of Deaths per 1000 of Population")
plt.show()

# %% [markdown]
# ## Potential Years of Life Loss 1907 - 2017

# %%
pyll = retrievingdata("PYLL.csv")
# Out:
# loading
# done

# %%
pyll
pyll['Males'] = pyll['Males'].astype(str).str.replace(',','').astype(int)
pyll['Females'] = pyll['Females'].astype(str).str.replace(',','').astype(int)
pyll['Total'] = pyll['Total'].astype(str).str.replace(',','').astype(int)
pyll[['Males','Females','Total']] = pyll[['Males','Females','Total']].div(1000)

# %%
plt.figure(figsize=(20, 10))
sns.set_style("whitegrid")
plt.plot(pyll['Years'], pyll['Males'], label="Males", color='#6873E3')
plt.plot(pyll['Years'], pyll['Females'], label="Females", color='#E368C5')
plt.plot(pyll['Years'], pyll['Total'], label="Total", color='#68E387')
plt.legend(prop={"size":15})
plt.title("Potential Years of Life Loss 1907 to 2017", fontsize=28, fontweight='bold')
plt.xlabel("Years")
plt.ylabel("Potential Years of Life Loss per 1000 of Population")
plt.show()

# %% [markdown]
# ## Life Expectancy from Birth 1977 - 2015

# %%
life_expectancy = retrievingdata("LIfe_Expectancy.csv")
# Out:
# loading
# done

# %%
life_expectancy
# Out:
#          Year  Males  Females
# 0   1881–1890   47.2     50.8
# 1   1891–1900   51.1     54.8
# 2   1901–1910   55.2     58.8
# 3   1920–1922   59.2     63.3
# 4   1932–1934   63.5     67.1
# 5   1946–1948   66.1     70.6
# 6   1953–1955   67.1     72.8
# 7   1960–1962   67.9     74.2
# 8   1965–1967   67.6     74.2
# 9   1970–1972   67.8     74.5
# 10  1975–1977   69.6     76.6
# 11  1980–1982   71.2     78.3
# 12  1985–1987   72.7     79.2
# 13  1990–1992   74.3     80.4
# 14  1993–1995   75.0     80.8
# 15  1994–1996   75.2     81.1
# 16  1995–1997   75.6     81.3
# 17  1996–1998   75.9     81.5
# 18  1997–1999   76.2     81.8
# 19  1998–2000   76.6     82.0
# 20  1999–2001   77.0     82.4
# 21  2000–2002   77.4     82.6
# 22  2001–2003   77.8     82.8
# 23  2002–2004   78.1     83.0
# 24  2003–2005   78.5     83.3
# 25  2004–2006   78.7     83.5
# 26  2005–2007   79.0     83.7
# 27  2006–2008   79.2     83.7
# 28  2007–2009   79.3     83.9
# 29  2008–2010   79.5     84.0
# ...

# %%
plt.figure(figsize=(20, 10))
sns.set_style("whitegrid")
plt.plot(life_expectancy['Year'], life_expectancy['Males'], label="Males", color='#6873E3')
plt.plot(life_expectancy['Year'], life_expectancy['Females'], label="Females", color='#E368C5')
plt.legend(prop={"size":15})
plt.xticks(rotation=45, ha="right")
plt.title("Life Expectancy 1907 to 2017", fontsize=28, fontweight='bold')
plt.xlabel("Years")
plt.ylabel("Potential Years of Life Loss per 1000 of Population")
plt.show()

# %% [markdown]
# ## Death by Age Group

# %%
age_group = retrievingdata("Deaths_sex_age_group.csv")
# Out:
# loading
# done

# %%
refinedage_group = age_group[['Age','Males','Females']].iloc[0:21]
refinedage_group
# Out:
#       Age    Males  Females
# 0     0–4    665.0    544.0
# 1     5–9     66.0     57.0
# 2   10–14     87.0     53.0
# 3   15–19    291.0    152.0
# 4   20–24    506.0    173.0
# 5   25–29    601.0    241.0
# 6   30–34    748.0    341.0
# 7   35–39    919.0    476.0
# 8   40–44   1246.0    712.0
# 9   45–49   1856.0   1124.0
# 10  50–54   2398.0   1610.0
# 11  55–59   3603.0   2262.0
# 12  60–64   4834.0   2972.0
# 13  65–69   6768.0   4239.0
# 14  70–74   8793.0   5742.0
# 15  75–79  10440.0   7577.0
# 16  80–84  12340.0  10689.0
# 17  85–89  13879.0  15305.0
# 18  90–94   9514.0  15169.0
# 19  95–99   2920.0   7034.0
# 20    100    381.0   1577.0

# %%
#define x and y limits
y = range(0, len(refinedage_group))
x_male = refinedage_group['Males']
x_female = refinedage_group['Females']

fig, axes = plt.subplots(ncols=2, sharey=True, figsize=(20, 10))
fig.patch.set_facecolor('xkcd:white')
sns.set_style("whitegrid")
plt.figtext(.5,.9,"Number of Deaths by Age Group 2018", fontsize=20, ha='center', fontweight='bold')
     
axes[0].barh(y, x_male, align='center', color='lightblue')
axes[0].set(title='Males')
axes[1].barh(y, x_female, align='center', color='lightpink')
axes[1].set(title='Females')

#adjust grid parameters and specify labels for y-axis
axes[1].grid()
axes[0].set(yticks=y, yticklabels=refinedage_group['Age'])
axes[0].invert_xaxis()
axes[0].grid()
plt.show()

# %% [markdown]
# ## Leading Causes of Death

# %%
causes = retrievingdata('Leading_Causes_by_Age.csv')
# Out:
# loading
# done

# %%
causes['Number of Deaths'] = causes['Number of Deaths'].astype(str).astype(int)

# %%
all_ages = causes.loc[causes['Age'] == 'All ages']
Under_1 = causes.loc[causes['Age'] == 'Under 1']
Group1 = causes.loc[21:40]
Group2 = causes.loc[41:61]
Group3 = causes.loc[62:81]
Group4 = causes.loc[82:101]
Group5 = causes.loc[102:121]
Group6 = causes.loc[122:140]
Group7 = causes.loc[141:160]
Group8 = causes.loc[161:180]

# %%
plt.figure(figsize=(20, 10))
my_range = range(1,len(all_ages.index)+1)
ordered_all_ages = all_ages.sort_values(by='Number of Deaths')
# Creates the Horizontal Lines 
plt.hlines(y=my_range, xmin=0, xmax=ordered_all_ages['Number of Deaths'], color="skyblue")
plt.plot(ordered_all_ages['Number of Deaths'], my_range, "o")
# Creates Categories on y-axis
plt.yticks(my_range, ordered_all_ages['Cause'])
# Labelling 
plt.ylabel("Cause of Death", fontsize=15)
plt.xlabel("Number of Deaths", fontsize=15)
plt.title("Top 20 Causes of Death in Australia 2018", loc='left', fontsize=24, fontweight="bold")
# Out:
# Text(0.0, 1.0, 'Top 20 Causes of Death in Australia 2018')

# %%
my_circle = plt.Circle((0,0),0.7, color='white')
plt.figure(figsize=(30, 15))
plt.pie(all_ages['Number of Deaths'], labels=all_ages['Cause'], colors=['#E53935','#F4511E','#FB8C00','#FFB300','#FDD835','#C0CA33','#7CB342','#43A047','#00897B','#A2D9CE','#17A589','#00ACC1','#039BE5','#1E88E5','#3949AB','#7D3C98','#5E35B1','#884EA0','#E91E63','#EC407A'])
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.title(label= "Top 20 Causes of Death in Australia 2018", fontsize=28, fontweight='bold')
plt.show()

# %%
y_pos = np.arange(len(all_ages['Cause']))
plt.figure(figsize=(30, 15))
plt.bar(y_pos, all_ages['Number of Deaths'], color=['#E53935','#F4511E','#FB8C00','#FFB300','#FDD835','#C0CA33','#7CB342','#43A047','#00897B','#A2D9CE','#17A589','#00ACC1','#039BE5','#1E88E5','#3949AB','#7D3C98','#5E35B1','#884EA0','#E91E63','#EC407A'])
plt.xticks(y_pos, all_ages['Cause'], rotation=45, ha="right")
plt.xlabel("Number of Deaths", fontsize=20)
plt.ylabel("Causes of Death", fontsize=20)
plt.show()

# %%
# Insert Graph of 2008-2018 Changes in the Top 20 Causes of Death
# This will be a Line Graph with  y  axis = number of deahts, x-axis = year and the diff lines will be the States and All of Australia

# %%
plt.figure(figsize=(30, 40))
data1 = pd.pivot_table(Top20, values='Number of Deaths', index=['Cause'], columns='Age')
sns.heatmap(data1, cmap='PuBuGn')
plt.title("Number of Deaths by Top 20 Causes for each Age Group Australia 2018", fontsize=28,fontweight='bold', loc='left')
plt.xlabel("Age", fontsize=20)
plt.ylabel("Cause", fontsize=20)
plt.show()

# %%
my_circle = plt.Circle((0,0),0.7, color='white')
plt.figure(figsize=(30, 15))
plt.pie(Group1['Number of Deaths'], labels=Group1['Cause'], colors=['#D7BDE2','#F1948A','#FAD7A0','#F5CBA7','#80DEEA','#E91E63','#FFF59D','#17A589','#A9DFBF','#A2D9CE','#43A047','#A3E4D7','#AED6F1','#5DADE2','#F48FB1','#EFEBE9','#F5F5F5','#ECEFF1','#A2D9CE','#FCE4EC'])
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.title(label= "Top 20 Causes of Death for Ages 1-14 Australia 2018", fontsize=28, fontweight='bold')
plt.show()

# %%
y_pos = np.arange(len(Group1['Cause']))
plt.figure(figsize=(30, 15))
sns.set_style("whitegrid")
plt.bar(y_pos, Group1['Number of Deaths'], color=['#D7BDE2','#F1948A','#FAD7A0','#F5CBA7','#80DEEA','#E91E63','#FFF59D','#17A589','#A9DFBF','#A2D9CE','#43A047','#A3E4D7','#AED6F1','#5DADE2','#F48FB1','#EFEBE9','#F5F5F5','#ECEFF1','#A2D9CE','#FCE4EC'])
plt.xticks(y_pos, Group1['Cause'], rotation=45, ha="right")
plt.xlabel("Number of Deaths", fontsize=20)
plt.ylabel("Causes of Death", fontsize=20)
plt.show()

# %%
my_circle = plt.Circle((0,0),0.7, color='white')
plt.figure(figsize=(30, 15))
plt.pie(Group2['Number of Deaths'], labels=Group2['Cause'], colors=['#17A589','#D7BDE2','#BBDEFB','#F5CBA7','#E91E63','#F9E79F','#FAD7A0','#ABEBC6','#80DEEA','#A2D9CE','#A3E4D7','#E0E0E0','#3949AB','#BCAAA4','#A9CCE3','#AED6F1','#FAE5D3','#FCE4EC','#D6DBDF','#F48FB1','#7CB342'])
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.title(label= "Top 20 Causes of Death for Ages 15-24 Australia 2018", fontsize=28, fontweight='bold')
plt.show()

# %%
y_pos = np.arange(len(Group2['Cause']))
plt.figure(figsize=(30, 15))
plt.bar(y_pos, Group2['Number of Deaths'], color=['#17A589','#D7BDE2','#BBDEFB','#F5CBA7','#E91E63','#F9E79F','#FAD7A0','#ABEBC6','#80DEEA','#A2D9CE','#A3E4D7','#E0E0E0','#3949AB','#BCAAA4','#A9CCE3','#AED6F1','#FAE5D3','#FCE4EC','#D6DBDF','#F48FB1','#7CB342'])
plt.xticks(y_pos, Group2['Cause'], rotation=45, ha="right")
plt.xlabel("Number of Deaths", fontsize=20)
plt.ylabel("Causes of Death", fontsize=20)
plt.show()

# %%
my_circle = plt.Circle((0,0),0.7, color='white')
plt.figure(figsize=(30, 15))
plt.pie(Group3['Number of Deaths'], labels=Group3['Cause'], colors=['#17A589','#BBDEFB','#D7BDE2','#E53935','#F9E79F','#FFF59D','#E91E63','#E3F2FD','#A9CCE3','#A9DFBF','#FB8C00','#FFB300','#7CB342','#FFCCBC','#FCE4EC','#F3E5F5','#EDE7F6','#E8EAF6','#E3F2FD','#EDBB99'])
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.title(label= "Top 20 Causes of Death for Ages 25-44 Australia 2018", fontsize=28, fontweight='bold')
plt.show()

# %%
y_pos = np.arange(len(Group3['Cause']))
plt.figure(figsize=(30, 15))
plt.bar(y_pos, Group3['Number of Deaths'], color=['#17A589','#BBDEFB','#D7BDE2','#E53935','#F9E79F','#FFF59D','#E91E63','#E3F2FD','#A9CCE3','#A9DFBF','#FB8C00','#FFB300','#7CB342','#FFCCBC','#FCE4EC','#F3E5F5','#EDE7F6','#E8EAF6','#E3F2FD','#EDBB99'])
plt.xticks(y_pos, Group3['Cause'], rotation=45, ha="right")
plt.xlabel("Number of Deaths", fontsize=20)
plt.ylabel("Causes of Death", fontsize=20)
plt.show()

# %%
my_circle = plt.Circle((0,0),0.7, color='white')
plt.figure(figsize=(30, 15))
plt.pie(Group4['Number of Deaths'], labels=Group4['Cause'], colors=['#E53935','#FFB300','#C0CA33','#17A589','#00ACC1','#E3F2FD','#FB8C00','#FDD835','#039BE5','#7CB342','#EC407A','#BBDEFB','#FAD7A0','#1E88E5','#E91E63','#EF5350','#D7BDE2','#FFCCBC','#64B5F6','#FFEBEE'])
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.title(label= "Top 20 Causes of Death for Ages 45-64 Australia 2018", fontsize=28, fontweight='bold')
plt.show()

# %%
y_pos = np.arange(len(Group4['Cause']))
plt.figure(figsize=(30, 15))
plt.bar(y_pos, Group4['Number of Deaths'], color=['#E53935','#FFB300','#C0CA33','#17A589','#00ACC1','#E3F2FD','#FB8C00','#FDD835','#039BE5','#7CB342','#EC407A','#BBDEFB','#FAD7A0','#1E88E5','#E91E63','#EF5350','#D7BDE2','#FFCCBC','#64B5F6','#FFEBEE'])
plt.xticks(y_pos, Group4['Cause'], rotation=45, ha="right")
plt.xlabel("Number of Deaths", fontsize=20)
plt.ylabel("Causes of Death", fontsize=20)
plt.show()

# %%
my_circle = plt.Circle((0,0),0.7, color='white')
plt.figure(figsize=(30, 15))
plt.pie(Group5['Number of Deaths'], labels=Group5['Cause'], colors=['#FFB300','#E53935','#FDD835','#C0CA33','#FB8C00','#7CB342','#039BE5','#00ACC1','#A2D9CE','#A2D9CE','#1E88E5','#EC407A','#A9CCE3','#80DEEA','#EF5350','#EDE7F6','#FAD7A0','#FFCCBC','#64B5F6','#F48FB1'])
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.title(label= "Top 20 Causes of Death for Ages 65-74 Australia 2018", fontsize=28, fontweight='bold')
plt.show()

# %%
y_pos = np.arange(len(Group5['Cause']))
plt.figure(figsize=(30, 15))
plt.bar(y_pos, Group5['Number of Deaths'], color=['#FFB300','#E53935','#FDD835','#C0CA33','#FB8C00','#7CB342','#039BE5','#00ACC1','#A2D9CE','#A2D9CE','#1E88E5','#EC407A','#A9CCE3','#80DEEA','#EF5350','#EDE7F6','#FAD7A0','#FFCCBC','#64B5F6','#F48FB1'])
plt.xticks(y_pos, Group5['Cause'], rotation=45, ha="right")
plt.xlabel("Number of Deaths", fontsize=20)
plt.ylabel("Causes of Death", fontsize=20)
plt.show()

# %%
my_circle = plt.Circle((0,0),0.7, color='white')
plt.figure(figsize=(30, 15))
plt.pie(Group6['Number of Deaths'], labels=Group6['Cause'], colors=['#E53935','#F4511E','#FB8C00','#FFB300','#FDD835','#C0CA33','#7CB342','#A9DFBF','#039BE5','#1E88E5','#A3E4D7','#00897B','#43A047','#3949AB','#00ACC1','#80DEEA','#884EA0','#7D3C98','#F8BBD0'])
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.title(label= "Top 20 Causes of Death for Ages 75-84 Australia 2018", fontsize=28, fontweight='bold')
plt.show()

# %%
y_pos = np.arange(len(Group6['Cause']))
plt.figure(figsize=(30, 15))
plt.bar(y_pos, Group6['Number of Deaths'], color=['#E53935','#F4511E','#FB8C00','#FFB300','#FDD835','#C0CA33','#7CB342','#A9DFBF','#039BE5','#1E88E5','#A3E4D7','#00897B','#43A047','#3949AB','#00ACC1','#80DEEA','#884EA0','#7D3C98','#F8BBD0'])
plt.xticks(y_pos, Group6['Cause'], rotation=45, ha="right")
plt.xlabel("Number of Deaths", fontsize=20)
plt.ylabel("Causes of Death", fontsize=20)
plt.show()

# %%
my_circle = plt.Circle((0,0),0.7, color='white')
plt.figure(figsize=(30, 15))
plt.pie(Group7['Number of Deaths'], labels=Group7['Cause'], colors=['#E53935','#F4511E','#FB8C00','#FDD835','#00897B','#43A047','#7CB342','#3949AB','#7D3C98','#A2D9CE','#C0CA33','#A2D9CE','#5E35B1','#884EA0','#9FA8DA','#1E88E5','#C39BD3','#5DADE2','#E91E63','#FF8A65'])
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.title(label= "Top 20 Causes of Death for Ages 85-94 Australia 2018", fontsize=28, fontweight='bold')
plt.show()

# %%
y_pos = np.arange(len(Group7['Cause']))
plt.figure(figsize=(30, 15))
plt.bar(y_pos, Group7['Number of Deaths'], color=['#E53935','#F4511E','#FB8C00','#FDD835','#00897B','#43A047','#7CB342','#3949AB','#7D3C98','#A2D9CE','#C0CA33','#A2D9CE','#5E35B1','#884EA0','#9FA8DA','#1E88E5','#C39BD3','#5DADE2','#E91E63','#FF8A65'])
plt.xticks(y_pos, Group7['Cause'], rotation=45, ha="right")
plt.xlabel("Number of Deaths", fontsize=20)
plt.ylabel("Causes of Death", fontsize=20)
plt.show()

# %%
my_circle = plt.Circle((0,0),0.7, color='white')
plt.figure(figsize=(30, 15))
plt.pie(Group8['Number of Deaths'], labels=Group8['Cause'], colors=['#F4511E','#E53935','#FB8C00','#43A047','#00897B','#5E35B1','#7D3C98','#FDD835','#3949AB','#884EA0','#E91E63','#7CB342','#9FA8DA','#C0CA33','#FF8A65','#FFEE58','#A5D6A7','#5DADE2','#4DD0E1','#A2D9CE'])
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.title(label= "Top 20 Causes of Death for Ages 95+ Australia 2018", fontsize=28, fontweight='bold')
plt.show()

# %%
y_pos = np.arange(len(Group8['Cause']))
plt.figure(figsize=(30, 15))
plt.bar(y_pos, Group8['Number of Deaths'], color=['#F4511E','#E53935','#FB8C00','#43A047','#00897B','#5E35B1','#7D3C98','#FDD835','#3949AB','#884EA0','#E91E63','#7CB342','#9FA8DA','#C0CA33','#FF8A65','#FFEE58','#A5D6A7','#5DADE2','#4DD0E1','#A2D9CE'])
plt.xticks(y_pos, Group8['Cause'], rotation=45, ha="right")
plt.xlabel("Number of Deaths", fontsize=20)
plt.ylabel("Causes of Death", fontsize=20)
plt.show()

# %%
heatmap_causes = causes[causes.Age != 'All ages']

# %%
Top20 = causes[(causes['Cause'] == 'Coronary heart disease (I20–I25)')| (causes['Cause'] == 'Dementia and Alzheimer disease (F01, F03, G30)')| (causes['Cause'] == 'Cerebrovascular disease (I60–I69)')| (causes['Cause'] == 'Lung cancer (C33, C34)')| (causes['Cause'] == 'Chronic obstructive pulmonary disease (COPD) (J40–J44)')| (causes['Cause'] == 'Colorectal cancer (C18–C20, C26.0)')| (causes['Cause'] == 'Diabetes (E10–E14)')| (causes['Cause'] == 'Influenza and pneumonia (J09–J18)')| (causes['Cause'] == 'Heart failure and complications and ill-defined heart disease (I50–I51)')| (causes['Cause'] == 'Prostate cancer (C61)')| (causes['Cause'] == 'Suicide (X60–X84)')| (causes['Cause'] == 'Breast cancer (C50)')| (causes['Cause'] == 'Pancreatic cancer (C25)')| (causes['Cause'] == 'Cancer of unknown or ill-defined primary site (C26, C39, C76–C80 excl. C26.0)')| (causes['Cause'] == 'Accidental falls (W00–W19)')| (causes['Cause'] == 'Cardiac arrhythmias (I47–I49)')| (causes['Cause'] == 'Hypertensive disease (I10–I15)')| (causes['Cause'] == 'Kidney failure (N17–N19)')| (causes['Cause'] == 'Other ill-defined causes (R00–R94, R96–R99, I46.9, I95.9, I99, J96.0, J96.9, P28.5)')| (causes['Cause'] == 'Liver cancer (C22)')][causes.Age != 'All ages'][causes.Age != 'Under 1']
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# From the heatmap the highest percentage of overall deaths of each age group by a certain cause are:
# - 1 to 14
#     1. Land Transport Accidents
#     2. Certain Conditions originating in the perintal period and deformations
#     3. Brain Cancer
# - 15 to 24:
#     1. Suicide
#     2. Land Transport Accidents
#     3. Accidental Poisoning
# - 25 to 44:
#     1. Suicide
#     2. Accidental Poisoning
#     3. Land Transport Accidents
# - 45 to 64:
#     1. Coronary Heart Disease
#     2. Lung Cancer
#     3. Colorectal Cancer
# - 65 to 74:
#     1. Lung Cancer
#     2. Coronary Heart Disease
#     3. Chronic Obstructive Pulmonary Disease
# - 75 to 84:
#     1. Coronary Heart Disease
#     2. Dementia and Alzheimer Disease
#     3. Cerebrovascular Disease
# - 85 to 94:
#     1. Coronary Heart Disease
#     2. Dementia and Alzheimer Disease
#     3. Cerebrovascular Disease
# - 95+:
#     1. Dementia and Alzheimer Disease
#     2. Coronary Heart Disease
#     3. Cerebrovascular Disease
#
# In all three age groups land transport accidents takes a high percentage of death despite it not being in the Top 20 Main Causes of death in 2018, however suicide takes first place in age groups 15 to 24 and 25 to 44.
#
# Now let's look at

# %% [markdown]
# ## Child Death Rates 1907 - 2017

# %%
child_death = retrievingdata("Child_Deaths.csv")
# Out:
# loading
# done

# %%
child_death
# Out:
#      Years  Males Females   Total
# 0     1907  6,482   5,341  11,823
# 1     1908  6,339   5,029  11,368
# 2     1909  5,927   4,786  10,713
# 3     1910  6,404   5,119  11,523
# 4     1911  6,126   4,871  10,997
# ..     ...    ...     ...     ...
# 106   2013    709     601   1,310
# 107   2014    636     555   1,191
# 108   2015    662     539   1,201
# 109   2016    654     507   1,161
# 110   2017    665     544   1,209
#
# [111 rows x 4 columns]

# %% [markdown]
# ## Number of Deaths of Australia in 2018 by State

# %%
retrievingdata("")
# Out:
# Insert file
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-34-977ed6bbe2de> in <module>
# ----> 1 retrievingdata("")
#
# <ipython-input-23-af933006c53f> in retrievingdata(filepath)
#       5     else:
#       6         print("Insert file")
# ----> 7     return(pd.read_csv(filepath,low_memory=False))
#
# ...

# %% [markdown]
# We can also get the list of columns out of the data frame

# %%
mortality_data1.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-239e9dad9e0b> in <module>
# ----> 1 mortality_data1.columns
#
# NameError: name 'mortality_data1' is not defined
